# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
apple = yf.download("AAPL",start = "2010-01-01" , end = "2023-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.496294
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.507527
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.404016
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.392178
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.434675
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.477127
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.652435
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.674026
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.233658
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.552719
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
tickers = ["SPY","AAPL","KO","IFCI.NS"]

# %%
stocks = yf.download(tickers,start = "2010-01-01" , end = "2023-01-01")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
stocks
# Out:
#              Adj Close                                         Close  \
#                   AAPL    IFCI.NS         KO         SPY        AAPL
# Date
# 2010-01-04    6.496294  46.586529  18.793245   87.791763    7.643214
# 2010-01-05    6.507525  47.155651  18.565897   88.024185    7.656429
# 2010-01-06    6.404015  46.749134  18.559315   88.086143    7.534643
# 2010-01-07    6.392177  47.887379  18.513189   88.457962    7.520714
# 2010-01-08    6.434674  46.871094  18.170530   88.752342    7.570714
# ...                ...        ...        ...         ...         ...
# 2022-12-26         NaN  13.100000        NaN         NaN         NaN
# 2022-12-27  129.652435  13.200000  63.239597  378.543793  130.029999
# 2022-12-28  125.674019  13.550000  62.609272  373.839264  126.040001
# 2022-12-29  129.233658  13.550000  62.983532  380.568512  129.610001
# 2022-12-30  129.552719  13.800000  62.648666  379.566040  129.929993
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3367 entries, 2010-01-04 to 2022-12-30
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, AAPL)     3272 non-null   float64
#  1   (Adj Close, IFCI.NS)  3209 non-null   float64
#  2   (Adj Close, KO)       3272 non-null   float64
#  3   (Adj Close, SPY)      3272 non-null   float64
#  4   (Close, AAPL)         3272 non-null   float64
#  5   (Close, IFCI.NS)      3209 non-null   float64
#  6   (Close, KO)           3272 non-null   float64
#  7   (Close, SPY)          3272 non-null   float64
#  8   (High, AAPL)          3272 non-null   float64
#  9   (High, IFCI.NS)       3209 non-null   float64
#  10  (High, KO)            3272 non-null   float64
#  11  (High, SPY)           3272 non-null   float64
#  12  (Low, AAPL)           3272 non-null   float64
#  13  (Low, IFCI.NS)        3209 non-null   float64
# ...

# %%
stocks.to_csv("xyz.csv")

# %%
stocks = pd.read_csv("xyz.csv",header=[0,1],index_col = [0],parse_dates = [0])

# %%
stocks
# Out:
#              Adj Close                                         Close  \
#                   AAPL    IFCI.NS         KO         SPY        AAPL
# Date
# 2010-01-04    6.496294  46.586529  18.793245   87.791763    7.643214
# 2010-01-05    6.507525  47.155651  18.565897   88.024185    7.656429
# 2010-01-06    6.404015  46.749134  18.559315   88.086143    7.534643
# 2010-01-07    6.392177  47.887379  18.513189   88.457962    7.520714
# 2010-01-08    6.434674  46.871094  18.170530   88.752342    7.570714
# ...                ...        ...        ...         ...         ...
# 2022-12-26         NaN  13.100000        NaN         NaN         NaN
# 2022-12-27  129.652435  13.200000  63.239597  378.543793  130.029999
# 2022-12-28  125.674019  13.550000  62.609272  373.839264  126.040001
# 2022-12-29  129.233658  13.550000  62.983532  380.568512  129.610001
# 2022-12-30  129.552719  13.800000  62.648666  379.566040  129.929993
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',    'AAPL'),
#             ('Adj Close', 'IFCI.NS'),
#             ('Adj Close',      'KO'),
#             ('Adj Close',     'SPY'),
#             (    'Close',    'AAPL'),
#             (    'Close', 'IFCI.NS'),
#             (    'Close',      'KO'),
#             (    'Close',     'SPY'),
#             (     'High',    'AAPL'),
#             (     'High', 'IFCI.NS'),
#             (     'High',      'KO'),
#             (     'High',     'SPY'),
#             (      'Low',    'AAPL'),
#             (      'Low', 'IFCI.NS'),
#             (      'Low',      'KO'),
#             (      'Low',     'SPY'),
#             (     'Open',    'AAPL'),
#             (     'Open', 'IFCI.NS'),
#             (     'Open',      'KO'),
#             (     'Open',     'SPY'),
#             (   'Volume',    'AAPL'),
#             (   'Volume', 'IFCI.NS'),
#             (   'Volume',      'KO'),
#             (   'Volume',     'SPY')],
#            )

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([   ('Adj Close', 'AAPL'), ('Adj Close', 'IFCI.NS'),
#             ('Adj Close', 'KO'),     ('Adj Close', 'SPY'),
#               ('Close', 'AAPL'),     ('Close', 'IFCI.NS'),
#                 ('Close', 'KO'),         ('Close', 'SPY'),
#                ('High', 'AAPL'),      ('High', 'IFCI.NS'),
#                  ('High', 'KO'),          ('High', 'SPY'),
#                 ('Low', 'AAPL'),       ('Low', 'IFCI.NS'),
#                   ('Low', 'KO'),           ('Low', 'SPY'),
#                ('Open', 'AAPL'),      ('Open', 'IFCI.NS'),
#                  ('Open', 'KO'),          ('Open', 'SPY'),
#              ('Volume', 'AAPL'),    ('Volume', 'IFCI.NS'),
#                ('Volume', 'KO'),        ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, IFCI.NS)  (Adj Close, KO)  \
# Date
# 2010-01-04           6.496294             46.586529        18.793245
# 2010-01-05           6.507525             47.155651        18.565897
# 2010-01-06           6.404015             46.749134        18.559315
# 2010-01-07           6.392177             47.887379        18.513189
# 2010-01-08           6.434674             46.871094        18.170530
# ...                       ...                   ...              ...
# 2022-12-26                NaN             13.100000              NaN
# 2022-12-27         129.652435             13.200000        63.239597
# 2022-12-28         125.674019             13.550000        62.609272
# 2022-12-29         129.233658             13.550000        62.983532
# 2022-12-30         129.552719             13.800000        62.648666
#
#             (Adj Close, SPY)  (Close, AAPL)  (Close, IFCI.NS)  (Close, KO)  \
# Date
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                                         Close  \
#                   AAPL    IFCI.NS         KO         SPY        AAPL
# Date
# 2010-01-04    6.496294  46.586529  18.793245   87.791763    7.643214
# 2010-01-05    6.507525  47.155651  18.565897   88.024185    7.656429
# 2010-01-06    6.404015  46.749134  18.559315   88.086143    7.534643
# 2010-01-07    6.392177  47.887379  18.513189   88.457962    7.520714
# 2010-01-08    6.434674  46.871094  18.170530   88.752342    7.570714
# ...                ...        ...        ...         ...         ...
# 2022-12-26         NaN  13.100000        NaN         NaN         NaN
# 2022-12-27  129.652435  13.200000  63.239597  378.543793  130.029999
# 2022-12-28  125.674019  13.550000  62.609272  373.839264  126.040001
# 2022-12-29  129.233658  13.550000  62.983532  380.568512  129.610001
# 2022-12-30  129.552719  13.800000  62.648666  379.566040  129.929993
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                               Close  \
#               AAPL      IFCI.NS           KO          SPY         AAPL
# count  3272.000000  3209.000000  3272.000000  3272.000000  3272.000000
# mean     49.326076    23.339098    36.195943   217.880213    51.321186
# std      47.685114    12.141024    11.358195   104.089536    47.357062
# min       5.829698     3.450000    16.635141    79.874100     6.858929
# 25%      16.578037    13.000000    28.006497   129.203831    18.967589
# 50%      27.306855    23.168222    34.114923   185.754883    29.815000
# 75%      54.793891    30.612270    43.468525   274.330360    56.777499
# max     180.434296    65.592628    63.820396   466.563293   182.009995
#
#                                                      High               ...  \
#            IFCI.NS           KO          SPY         AAPL      IFCI.NS  ...
# count  3209.000000  3272.000000  3272.000000  3272.000000  3209.000000  ...
# ...

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL    IFCI.NS         KO         SPY
# Date
# 2010-01-04    7.643214  57.299999  28.520000  113.330002
# 2010-01-05    7.656429  58.000000  28.174999  113.629997
# 2010-01-06    7.534643  57.500000  28.165001  113.709999
# 2010-01-07    7.520714  58.900002  28.094999  114.190002
# 2010-01-08    7.570714  57.650002  27.575001  114.570000
# ...                ...        ...        ...         ...
# 2022-12-26         NaN  13.100000        NaN         NaN
# 2022-12-27  130.029999  13.200000  64.209999  381.399994
# 2022-12-28  126.040001  13.550000  63.570000  376.660004
# 2022-12-29  129.610001  13.550000  63.950001  383.440002
# 2022-12-30  129.929993  13.800000  63.610001  382.429993
#
# [3367 rows x 4 columns]

# %%
# %matplotlib inline
#plt.style.use("seaborn")

# %%
close.plot()
plt.legend()
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2022-12-26           NaN
# 2022-12-27    130.029999
# 2022-12-28    126.040001
# 2022-12-29    129.610001
# 2022-12-30    129.929993
# Name: AAPL, Length: 3367, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL         7.643214
# IFCI.NS     57.299999
# KO          28.520000
# SPY        113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
nom = close.div(close.iloc[0]).mul(100)
nom
# Out:
#                    AAPL     IFCI.NS          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893  101.221642   98.790318  100.264710
# 2010-01-06    98.579511  100.349041   98.755261  100.335302
# 2010-01-07    98.397266  102.792325   98.509814  100.758846
# 2010-01-08    99.051443  100.610824   96.686537  101.094148
# ...                 ...         ...         ...         ...
# 2022-12-26          NaN   22.862130         NaN         NaN
# 2022-12-27  1701.247603   23.036649  225.140246  336.539299
# 2022-12-28  1649.044462   23.647470  222.896209  332.356832
# 2022-12-29  1695.752556   23.647470  224.228611  338.339360
# 2022-12-30  1699.939173   24.083770  223.036464  337.448148
#
# [3367 rows x 4 columns]

# %%
nom.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
close["IFCI.NS"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2022-12-26         NaN
# 2022-12-27  130.029999
# 2022-12-28  126.040001
# 2022-12-29  129.610001
# 2022-12-30  129.929993
#
# [3367 rows x 1 columns]

# %%
aapl.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
aapl.shift(periods = 1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2022-12-26  131.860001
# 2022-12-27         NaN
# 2022-12-28  130.029999
# 2022-12-29  126.040001
# 2022-12-30  129.610001
#
# [3367 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods= 1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2022-12-26         NaN  131.860001
# 2022-12-27  130.029999         NaN
# 2022-12-28  126.040001  130.029999
# 2022-12-29  129.610001  126.040001
# 2022-12-30  129.929993  129.610001
#
# [3367 rows x 2 columns]

# %%
new = aapl["AAPL"]-aapl["lag1"]

# %%
aapl["diff"] = new
aapl
# Out:
#                   AAPL        lag1      diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2022-12-26         NaN  131.860001       NaN
# 2022-12-27  130.029999         NaN       NaN
# 2022-12-28  126.040001  130.029999 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000
# 2022-12-30  129.929993  129.610001  0.319992
#
# [3367 rows x 3 columns]

# %%
aapl["diff"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
aapl["volat"] = aapl.AAPL.div(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      diff     volat
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08    7.570714    7.520714  0.050000  1.006648
# ...                ...         ...       ...       ...
# 2022-12-26         NaN  131.860001       NaN       NaN
# 2022-12-27  130.029999         NaN       NaN       NaN
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315
# 2022-12-29  129.610001  126.040001  3.570000  1.028324
# 2022-12-30  129.929993  129.610001  0.319992  1.002469
#
# [3367 rows x 4 columns]

# %%
aapl["volat"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
aapl["lag2"] = aapl.AAPL.diff(periods = 2)
aapl
# Out:
#                   AAPL        lag1      diff     volat      lag2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729       NaN
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.108571
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.135715
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.036071
# ...                ...         ...       ...       ...       ...
# 2022-12-26         NaN  131.860001       NaN       NaN       NaN
# 2022-12-27  130.029999         NaN       NaN       NaN -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315       NaN
# 2022-12-29  129.610001  126.040001  3.570000  1.028324 -0.419998
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  3.889992
#
# [3367 rows x 5 columns]

# %%
 aapl["volt2"] = aapl.AAPL.pct_change(periods = 2).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      diff     volat      lag2     volt2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729       NaN       NaN
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.108571 -1.420489
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.135715 -1.772563
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.036071  0.478733
# ...                ...         ...       ...       ...       ...       ...
# 2022-12-26         NaN  131.860001       NaN       NaN       NaN -0.279812
# 2022-12-27  130.029999         NaN       NaN       NaN -1.830002 -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315       NaN -4.413772
# 2022-12-29  129.610001  126.040001  3.570000  1.028324 -0.419998 -0.323001
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  3.889992  3.086315
#
# [3367 rows x 6 columns]

# %%
aapl["volt2"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
del aapl["volt2"]

# %%
aapl
# Out:
#                   AAPL        lag1      diff     volat      lag2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729       NaN
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.108571
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.135715
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.036071
# ...                ...         ...       ...       ...       ...
# 2022-12-26         NaN  131.860001       NaN       NaN       NaN
# 2022-12-27  130.029999         NaN       NaN       NaN -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315       NaN
# 2022-12-29  129.610001  126.040001  3.570000  1.028324 -0.419998
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  3.889992
#
# [3367 rows x 5 columns]

# %%
aapl.rename(columns = {"volat": "volatility"},inplace = True)

# %%
aapl
# Out:
#                   AAPL        lag1      diff  volatility      lag2
# Date
# 2010-01-04    7.643214         NaN       NaN         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215    1.001729       NaN
# 2010-01-06    7.534643    7.656429 -0.121786    0.984094 -0.108571
# 2010-01-07    7.520714    7.534643 -0.013929    0.998151 -0.135715
# 2010-01-08    7.570714    7.520714  0.050000    1.006648  0.036071
# ...                ...         ...       ...         ...       ...
# 2022-12-26         NaN  131.860001       NaN         NaN       NaN
# 2022-12-27  130.029999         NaN       NaN         NaN -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998    0.969315       NaN
# 2022-12-29  129.610001  126.040001  3.570000    1.028324 -0.419998
# 2022-12-30  129.929993  129.610001  0.319992    1.002469  3.889992
#
# [3367 rows x 5 columns]

# %%
aapl.AAPL.resample("M").last().pct_change(periods = 1).mul(100).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
aapl
del aapl["lag2"]
del aapl["volatility"]

# %%
ret = aapl.pct_change().dropna()
ret
# Out:
#                 AAPL      lag1       diff
# Date
# 2010-01-06 -0.015906  0.001729 -10.216000
# 2010-01-07 -0.001849 -0.015906  -0.885624
# 2010-01-08  0.006648 -0.001849  -4.589552
# 2010-01-11 -0.008821  0.006648  -2.335692
# 2010-01-12 -0.011375 -0.008821   0.278106
# ...              ...       ...        ...
# 2022-12-26  0.000000 -0.002798   0.000000
# 2022-12-27 -0.013878  0.000000   0.000000
# 2022-12-28 -0.030685 -0.013878   9.783920
# 2022-12-29  0.028324 -0.030685  -1.894737
# 2022-12-30  0.002469  0.028324  -0.910366
#
# [3363 rows x 3 columns]

# %%
ret.hist(figsize = (12,8),bins = 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-f55c510e27f7> in <cell line: 1>()
# ----> 1 ret.hist(figsize = (12,8),bins = 100)
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     229     """
#     230     plot_backend = _get_plot_backend(backend)
# --> 231     return plot_backend.hist_frame(
#     232         data,
#     233         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     518         if legend and can_set_label:
#     519             kwds["label"] = col
# ...

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3363 entries, 2010-01-06 to 2022-12-30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3363 non-null   float64
#  1   lag1    3363 non-null   float64
#  2   diff    3363 non-null   float64
# dtypes: float64(3)
# memory usage: 105.1 KB

# %%
ret.describe()
# Out:
#               AAPL         lag1         diff
# count  3363.000000  3363.000000  3363.000000
# mean      0.000994     0.001001          NaN
# std       0.017845     0.017851          NaN
# min      -0.128647    -0.128647         -inf
# 25%      -0.007322    -0.007322    -1.855299
# 50%       0.000345     0.000378    -0.931299
# 75%       0.010264     0.010271     0.000000
# max       0.119808     0.119808          inf

# %%
tickers = ["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(tickers,start = "2010-01-01",end = "2021-01-01")

# %%
stocks

# %%
newclose = stocks.loc[:,"Close"].copy()

# %%
newclose

# %%
norm = newclose.div(newclose.iloc[0]).mul(100)
norm

# %%
norm.plot()

# %%
ret = newclose.pct_change().dropna()

# %%
ret.describe()

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary

# %%
summary.plot.scatter(x = "std",y = "mean",figsize=(12,8),s =50,fontsize = 15)
for i in summary.index:
  plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size = 15)

# %%
ret

# %%
ret.cov()

# %%
ret.corr()

# %%
import seaborn as sns

# %%
plt.figure(figsize =(12,8))
sns.set(font_scale= 1.4)
sns.heatmap(ret.corr(),cmap = "Reds",annot = True,annot_kws = {"size":15},vmax = 0.6)
plt.show()

# %% [markdown]
# Challenge-1

# %%
tickers = ["RELIANCE.NS","IFCI.NS","TRIDENT.NS","RAMASTEEL.NS","TATAPOWER.NS"]

# %%
stocks = yf.download(tickers,start="2018-12-12",end = "2023-07-10")

# %%
stocks

# %%
close = stocks.loc[:,"Close"].copy()
close

# %%
ret = close.pct_change().dropna()
ret

# %%
ret.describe()

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)

# %%
summary

# %%
summary.plot.scatter(x = "std",y = "mean",figsize=(12,8),s =50,fontsize = 15)
for i in summary.index:
  plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size = 15)

# %%
ret.cov()
ret.corr()

# %%
plt.figure(figsize =(12,8))
sns.set(font_scale= 1.4)
sns.heatmap(ret.corr(),cmap = "Reds",annot = True,annot_kws = {"size":15},vmax = 0.6)
plt.show()

# %%
df = pd.DataFrame(index =[2016,2017,2018],data= [100,50,95],columns = ["price"] )

# %%
df

# %%
simplereturns = df.pct_change().dropna()
simplereturns

# %%
simplereturns.describe()

# %%
logret = np.log(df/df.shift(1)).dropna()

# %%
logret.mean()

# %%
100*np.exp(logret.mean()*2)

# %%
aapl = yf.download("SPY")

# %%
aapl.plot()

# %%
ac = aapl["Close"]

# %%
ac.dropna().to_frame()

# %%
ac.plot(figsize = (12,8),fontsize = 15)
plt.legend(loc = "upper left",fontsize = 15)
plt.show()

# %%
roll = ac.rolling(window = 15)

# %%
roll.mean()

# %%
roll.median()

# %%
spy = yf.download("SPY")

# %%
spy = spy["Close"]

# %%
spy = spy.to_frame()

# %%
spy

# %%
all_days = pd.date_range(start = "2010-12-30",end = "2020-01-01",freq = "D")
all_days

# %%
spy = spy.reindex(all_days)

# %%
spy

# %%
spy = spy.fillna(method = 'ffill')

# %%
apple = yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple = apple["Close"].to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-07-10  188.610001
# 2023-07-11  188.080002
# 2023-07-12  189.770004
# 2023-07-13  190.539993
# 2023-07-14  189.934998
#
# [10736 rows x 1 columns]

# %%
apple["d-ret"] = np.log(apple.div(apple.shift(1)))

# %%
apple.dropna(inplace =True )

# %%
su = apple["d-ret"].sum()

# %%
np.exp(su)
# Out:
# 1479.8439248751565

# %%
apple["cumret"] = apple["d-ret"].cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close     d-ret       cumret
# Date
# 1980-12-15    0.121652 -0.053581     0.947829
# 1980-12-16    0.112723 -0.076231     0.878261
# 1980-12-17    0.115513  0.024450     0.899998
# 1980-12-18    0.118862  0.028580     0.926092
# 1980-12-19    0.126116  0.059239     0.982610
# ...                ...       ...          ...
# 2023-07-10  188.610001 -0.010915  1469.520453
# 2023-07-11  188.080002 -0.002814  1465.391064
# 2023-07-12  189.770004  0.008945  1478.558410
# 2023-07-13  190.539993  0.004049  1484.557639
# 2023-07-14  189.934998 -0.003180  1479.843925
#
# [10735 rows x 3 columns]

# %%
apple["cumret"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
apple["d-ret"].mean()*252
# Out:
# 0.17135746251215855

# %%
apple["d-ret"].std()*np.sqrt(252)
# Out:
# 0.4535741946867109

# %%
apple["cummax"] = apple['cumret'].cummax()

# %%
apple
# Out:
#                  Close     d-ret       cumret       cummax
# Date
# 1980-12-15    0.121652 -0.053581     0.947829     0.947829
# 1980-12-16    0.112723 -0.076231     0.878261     0.947829
# 1980-12-17    0.115513  0.024450     0.899998     0.947829
# 1980-12-18    0.118862  0.028580     0.926092     0.947829
# 1980-12-19    0.126116  0.059239     0.982610     0.982610
# ...                ...       ...          ...          ...
# 2023-07-10  188.610001 -0.010915  1469.520453  1511.281921
# 2023-07-11  188.080002 -0.002814  1465.391064  1511.281921
# 2023-07-12  189.770004  0.008945  1478.558410  1511.281921
# 2023-07-13  190.539993  0.004049  1484.557639  1511.281921
# 2023-07-14  189.934998 -0.003180  1479.843925  1511.281921
#
# [10735 rows x 4 columns]

# %%
apple[["cumret","cummax"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
apple["ddown"] = apple["cummax"]-apple["cumret"]

# %%
apple
# Out:
#                  Close     d-ret       cumret       cummax      ddown
# Date
# 1980-12-15    0.121652 -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723 -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513  0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862  0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116  0.059239     0.982610     0.982610   0.000000
# ...                ...       ...          ...          ...        ...
# 2023-07-10  188.610001 -0.010915  1469.520453  1511.281921  41.761468
# 2023-07-11  188.080002 -0.002814  1465.391064  1511.281921  45.890857
# 2023-07-12  189.770004  0.008945  1478.558410  1511.281921  32.723511
# 2023-07-13  190.539993  0.004049  1484.557639  1511.281921  26.724282
# 2023-07-14  189.934998 -0.003180  1479.843925  1511.281921  31.437996
#
# [10735 rows x 5 columns]

# %%
apple["ddown"].argmax()
# Out:
# 10604

# %%
apple.iloc[10604]
# Out:
# Close      125.019997
# d-ret       -0.010661
# cumret     974.070524
# cummax    1418.097708
# ddown      444.027184
# Name: 2023-01-05 00:00:00, dtype: float64

# %%
data = apple.Close.loc[(apple.index>='1990-01-01')]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1990-01-02    0.332589
# 1990-01-03    0.334821
# 1990-01-04    0.335938
# 1990-01-05    0.337054
# 1990-01-08    0.339286
# ...                ...
# 2023-07-10  188.610001
# 2023-07-11  188.080002
# 2023-07-12  189.770004
# 2023-07-13  190.539993
# 2023-07-14  189.934998
#
# [8448 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data["sma_s"] = data.Close.rolling(sma_s).mean()
data["sma_l"] = data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close     sma_s      sma_l
# Date
# 1990-01-02    0.332589       NaN        NaN
# 1990-01-03    0.334821       NaN        NaN
# 1990-01-04    0.335938       NaN        NaN
# 1990-01-05    0.337054       NaN        NaN
# 1990-01-08    0.339286       NaN        NaN
# ...                ...       ...        ...
# 2023-07-10  188.610001  179.2126  168.26220
# 2023-07-11  188.080002  179.6060  168.61100
# 2023-07-12  189.770004  180.0078  168.95540
# 2023-07-13  190.539993  180.4268  169.32370
# 2023-07-14  189.934998  180.8547  169.69755
#
# [8448 rows x 3 columns]

# %%
data.loc["2016"].plot(figsize =(12,8),title = "APPLE - SMA{} | SMA{}".format(sma_s,sma_l))
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1990-05-23    0.375000    0.364978    0.337243
# 1990-05-24    0.375000    0.365871    0.337668
# 1990-05-25    0.357143    0.366451    0.337891
# 1990-05-29    0.366071    0.366585    0.338192
# 1990-05-30    0.369420    0.366406    0.338516
# ...                ...         ...         ...
# 2023-07-10  188.610001  179.212600  168.262200
# 2023-07-11  188.080002  179.606000  168.611000
# 2023-07-12  189.770004  180.007800  168.955400
# 2023-07-13  190.539993  180.426800  169.323700
# 2023-07-14  189.934998  180.854700  169.697550
#
# [8349 rows x 3 columns]

# %%
data["pos"] = np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  pos
# Date
# 1990-05-23    0.375000    0.364978    0.337243    1
# 1990-05-24    0.375000    0.365871    0.337668    1
# 1990-05-25    0.357143    0.366451    0.337891    1
# 1990-05-29    0.366071    0.366585    0.338192    1
# 1990-05-30    0.369420    0.366406    0.338516    1
# ...                ...         ...         ...  ...
# 2023-07-10  188.610001  179.212600  168.262200    1
# 2023-07-11  188.080002  179.606000  168.611000    1
# 2023-07-12  189.770004  180.007800  168.955400    1
# 2023-07-13  190.539993  180.426800  169.323700    1
# 2023-07-14  189.934998  180.854700  169.697550    1
#
# [8349 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","pos"]].plot(figsize =(12,8),title = "APPLE - SMA{} | SMA{}".format(sma_s,sma_l),secondary_y = "pos")
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["ret"] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data
# Out:
#                  Close       sma_s       sma_l  pos       ret
# Date
# 1990-05-23    0.375000    0.364978    0.337243    1       NaN
# 1990-05-24    0.375000    0.365871    0.337668    1  0.000000
# 1990-05-25    0.357143    0.366451    0.337891    1 -0.048790
# 1990-05-29    0.366071    0.366585    0.338192    1  0.024691
# 1990-05-30    0.369420    0.366406    0.338516    1  0.009107
# ...                ...         ...         ...  ...       ...
# 2023-07-10  188.610001  179.212600  168.262200    1 -0.010915
# 2023-07-11  188.080002  179.606000  168.611000    1 -0.002814
# 2023-07-12  189.770004  180.007800  168.955400    1  0.008945
# 2023-07-13  190.539993  180.426800  169.323700    1  0.004049
# 2023-07-14  189.934998  180.854700  169.697550    1 -0.003180
#
# [8349 rows x 5 columns]

# %%
data["stat"] = data["ret"]*data.pos.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  pos       ret      stat
# Date
# 1990-05-23    0.375000    0.364978    0.337243    1       NaN       NaN
# 1990-05-24    0.375000    0.365871    0.337668    1  0.000000  0.000000
# 1990-05-25    0.357143    0.366451    0.337891    1 -0.048790 -0.048790
# 1990-05-29    0.366071    0.366585    0.338192    1  0.024691  0.024691
# 1990-05-30    0.369420    0.366406    0.338516    1  0.009107  0.009107
# ...                ...         ...         ...  ...       ...       ...
# 2023-07-10  188.610001  179.212600  168.262200    1 -0.010915 -0.010915
# 2023-07-11  188.080002  179.606000  168.611000    1 -0.002814 -0.002814
# 2023-07-12  189.770004  180.007800  168.955400    1  0.008945  0.008945
# 2023-07-13  190.539993  180.426800  169.323700    1  0.004049  0.004049
# 2023-07-14  189.934998  180.854700  169.697550    1 -0.003180 -0.003180
#
# [8349 rows x 6 columns]

# %%
data.dropna(inplace = True)

# %%
data[["ret","stat"]].sum()
# Out:
# ret     6.227511
# stat    1.750091
# dtype: float64

# %%
data[["ret","stat"]].describe()
# Out:
#                ret         stat
# count  8348.000000  8348.000000
# mean      0.000746     0.000210
# std       0.027708     0.027717
# min      -0.731248    -0.731248
# 25%      -0.012107    -0.012468
# 50%       0.000305     0.000009
# 75%       0.013946     0.013820
# max       0.286892     0.262362

# %%
data[["ret","stat"]].sum().apply(np.exp)
# Out:
# ret     506.493327
# stat      5.755129
# dtype: float64

# %%
data[["ret","stat"]].std()*np.sqrt(252)
# Out:
# ret     0.439848
# stat    0.439995
# dtype: float64

# %%
data.Close.plot(figsize = (12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
data["pos2"] = np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["stat2"] = data["ret"]*data.pos2.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  pos       ret      stat  pos2  \
# Date
# 1990-05-24    0.375000    0.365871    0.337668    1  0.000000  0.000000     1
# 1990-05-25    0.357143    0.366451    0.337891    1 -0.048790 -0.048790     1
# 1990-05-29    0.366071    0.366585    0.338192    1  0.024691  0.024691     1
# 1990-05-30    0.369420    0.366406    0.338516    1  0.009107  0.009107     1
# 1990-05-31    0.368304    0.366384    0.338806    1 -0.003025 -0.003025     1
# ...                ...         ...         ...  ...       ...       ...   ...
# 2023-07-10  188.610001  179.212600  168.262200    1 -0.010915 -0.010915     1
# 2023-07-11  188.080002  179.606000  168.611000    1 -0.002814 -0.002814     1
# 2023-07-12  189.770004  180.007800  168.955400    1  0.008945  0.008945     1
# 2023-07-13  190.539993  180.426800  169.323700    1  0.004049  0.004049     1
# 2023-07-14  189.934998  180.854700  169.697550    1 -0.003180 -0.003180     1
#
#                stat2
# ...

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  pos       ret      stat  pos2  \
# Date
# 1990-05-25    0.357143    0.366451    0.337891    1 -0.048790 -0.048790     1
# 1990-05-29    0.366071    0.366585    0.338192    1  0.024691  0.024691     1
# 1990-05-30    0.369420    0.366406    0.338516    1  0.009107  0.009107     1
# 1990-05-31    0.368304    0.366384    0.338806    1 -0.003025 -0.003025     1
# 1990-06-01    0.363839    0.366228    0.339085    1 -0.012197 -0.012197     1
# ...                ...         ...         ...  ...       ...       ...   ...
# 2023-07-10  188.610001  179.212600  168.262200    1 -0.010915 -0.010915     1
# 2023-07-11  188.080002  179.606000  168.611000    1 -0.002814 -0.002814     1
# 2023-07-12  189.770004  180.007800  168.955400    1  0.008945  0.008945     1
# 2023-07-13  190.539993  180.426800  169.323700    1  0.004049  0.004049     1
# 2023-07-14  189.934998  180.854700  169.697550    1 -0.003180 -0.003180     1
#
#                stat2
# ...

# %%
data[["ret","stat2"]].sum()
# Out:
# ret      6.227511
# stat2    3.988801
# dtype: float64

# %%
data[["ret","stat2"]].sum().apply(np.exp)
# Out:
# ret      506.493327
# stat2     53.990131
# dtype: float64

# %%
data[["ret","stat2"]].std()*np.sqrt(252)
# Out:
# ret      0.439874
# stat2    0.340901
# dtype: float64

# %%
## stat2 is better than stat 1

# %%
data[["stat","stat2"]].std()*np.sqrt(252)
# Out:
# stat     0.440021
# stat2    0.340901
# dtype: float64

# %%
def test_stat(stock,start,end,sma):
  df = yf.download(stock,start=start,end=end)
  data = df.Close.to_frame()
  data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
  data["sma_s"] = data.Close.rolling(int(sma[0])).mean()
  data["sma_l"] = data.Close.rolling(int(sma[1])).mean()
  data.dropna(inplace = True)
  data["pos"] = np.where(data["sma_s"]>data["sma_l"],1,-1)
  data["stat"] = data["returns"]*data.pos.shift(1)
  data.dropna(inplace = True)
  ret = np.exp(data["stat"].sum())
  std = data["stat"].std()*np.sqrt(252)
  return ret,std

# %%
test_stat("MSFT","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (0.39097954932295986, 0.2906766831415829)

# %%
test_stat("AAPL","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (16.540320732436786, 0.36699682903803943)

# %%
test_stat("TSLA","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3908153866370587, 0.4956456904999671)

# %%
test_stat("MRF.NS","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.2692123758962706, 0.36262593837597856)

# %%
from os import stat_result
class smabacktest():
  def __init__(self,symbol,sma_s,sma_l,start,end):
    self.symbol = symbol
    self.sma_s = sma_s
    self.sma_l = sma_l
    self.end = end
    self.start = start
    self.results = None
    self.get_data()

  def get_data(self):
    df = yf.download(self.symbol,start=self.start,end=self.end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["sma_s"] = data.Close.rolling(int(self.sma_s)).mean()
    data["sma_l"] = data.Close.rolling(int(self.sma_l)).mean()
    data.dropna(inplace = True)
    self.data2 = data
    return data

  def test_result(self):
    data = self.data2.copy().dropna()
    data["pos"] = np.where(data["sma_s"]>data["sma_l"],1,-1)
    data["stat"] = data["returns"]*data.pos.shift(1)
    data.dropna(inplace = True)
    data["retbh"] = data["returns"].cumsum().apply(np.exp)
    data["stat_result"] = data["stat"].cumsum().apply(np.exp)
    perf = data["stat_result"].iloc[-1]
    outperf = perf-data["retbh"].iloc[-1]
    self.results = data

    ret = np.exp(data["stat"].sum())
    std = data["stat"].std()*np.sqrt(252)
    return round(perf,6),round(outperf,6)
  def plot_result(self):
    if self.results is None:
      print("run the test please")
    else:
      title="{}\sma_s{} | sma_l{}".format(self.symbol,self.sma_s,self.sma_l)
      self.results[["retbh","stat_result"]].plot(title=title ,figsize = (12,8))

# %%
tester = smabacktest("SPY",50,100,"2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_result()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_result()
